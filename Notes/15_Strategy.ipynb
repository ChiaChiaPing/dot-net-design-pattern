# %% [markdown]
# ## Introduction
# - 把各種low-level 可以互換的演算法（策略） 包裝成一個high-level 類別或介面
#     - 對於外部而言 , 我都是用策略, 至於策略的細節就由子類別/策略去實踐
#     - 可以把策略想像成是介面或是類別

# %% [markdown]
# ![%E8%9E%A2%E5%B9%95%E5%BF%AB%E7%85%A7%202020-05-02%20%E4%B8%8B%E5%8D%889.12.39.png](attachment:%E8%9E%A2%E5%B9%95%E5%BF%AB%E7%85%A7%202020-05-02%20%E4%B8%8B%E5%8D%889.12.39.png)

# %% [markdown]
# ## Equality and comparison Strategy
# - ICcomparable
# - delegate method 可以想像成是 class 拿來創建物件, 但他本質並不是創建物件而是去帶外部實際設計符合delegate 規範的方法。

# %% [markdown]
# ![%E8%9E%A2%E5%B9%95%E5%BF%AB%E7%85%A7%202020-05-02%20%E4%B8%8B%E5%8D%8810.25.00.png](attachment:%E8%9E%A2%E5%B9%95%E5%BF%AB%E7%85%A7%202020-05-02%20%E4%B8%8B%E5%8D%8810.25.00.png)
