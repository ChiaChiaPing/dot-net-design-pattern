# %% [markdown]
# ![%E8%9E%A2%E5%B9%95%E5%BF%AB%E7%85%A7%202020-03-21%20%E4%B8%8B%E5%8D%887.30.04.png](attachment:%E8%9E%A2%E5%B9%95%E5%BF%AB%E7%85%A7%202020-03-21%20%E4%B8%8B%E5%8D%887.30.04.png)

# %% [markdown]
# - Lexing : 把 structrued test input convert to colleciton(e.g. array) which contain lexical tokens
# - Parsing : 翻譯轉譯或是perform 在這個colleciton 被視為是lexical ttoken 的 element 去做相對應的操作

# %% [markdown]
# ### Recommend Tool : Antlr

# %%
str_ = "qootest"

# %%
def reverseString(inputString):
    if(len(inputString)==0):
        pass
    return inputString[-1] + reverseString(inputString[:-1])

# %%
reverseString(str_)
# Out:
# 'tsetooq'
