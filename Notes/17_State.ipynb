# %% [markdown]
# ![%E8%9E%A2%E5%B9%95%E5%BF%AB%E7%85%A7%202020-05-03%20%E4%B8%8A%E5%8D%8811.03.36.png](attachment:%E8%9E%A2%E5%B9%95%E5%BF%AB%E7%85%A7%202020-05-03%20%E4%B8%8A%E5%8D%8811.03.36.png)

# %% [markdown]
# ### Classic Implementation
# - 狀態的轉換與每一個狀態都用一個class 去包裝 => 浪費
# - 只能用該物件內定義的方法去change state 不能由外部去change state

# %% [markdown]
# ### Handmade State Machine
# - usgin Enum and involve in Trigger and previous/later state
# - using CCcentralized location(dictionary) 去管理 state and state's transitition

# %% [markdown]
# ### Switch-Based State Machine
# - 沒有centralization location
# - 直接用 switch case 搭配enum 直接在runtime 過程中assign state, switch state

# %% [markdown]
# ### StateLess - State Machine Library

# %% [markdown]
# ![%E8%9E%A2%E5%B9%95%E5%BF%AB%E7%85%A7%202020-05-03%20%E4%B8%8B%E5%8D%8812.41.12.png](attachment:%E8%9E%A2%E5%B9%95%E5%BF%AB%E7%85%A7%202020-05-03%20%E4%B8%8B%E5%8D%8812.41.12.png)
