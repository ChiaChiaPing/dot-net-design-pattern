# %% [markdown]
# ## 1. Introduction

# %% [markdown]
# ![%E8%9E%A2%E5%B9%95%E5%BF%AB%E7%85%A7%202020-04-12%20%E4%B8%8B%E5%8D%8812.56.54.png](attachment:%E8%9E%A2%E5%B9%95%E5%BF%AB%E7%85%A7%202020-04-12%20%E4%B8%8B%E5%8D%8812.56.54.png)

# %% [markdown]
# ### 基本上就是create 一個物件（被視為是token 或是 handler）去存取 其他system component 物件（內的資訊）更動的狀況
#     -- 可以 健一個list 去存放該其他物件他所有變動的狀況，做rollback, 或是利用 index 的方式去tracking list 去做到 undo/redo 的function

# %% [markdown]
# ![%E8%9E%A2%E5%B9%95%E5%BF%AB%E7%85%A7%202020-04-12%20%E4%B8%8B%E5%8D%882.24.05.png](attachment:%E8%9E%A2%E5%B9%95%E5%BF%AB%E7%85%A7%202020-04-12%20%E4%B8%8B%E5%8D%882.24.05.png)
