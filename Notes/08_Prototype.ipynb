# %% [markdown]
# ## Prototype Introduction
# - Complicated Object aren't designed from scratch
# - An existing ( partially or fully constructed ) design is a Prototype
# - we can copy(clone) the prototype and customize it.
#     - deep copy : 不同的變數不指向同一個物件，而是指向不同的物件，完全地複製（不會 refer to 同一個物件 ）

# %% [markdown]
# ![%E8%9E%A2%E5%B9%95%E5%BF%AB%E7%85%A7%202019-09-30%20%E4%B8%8B%E5%8D%889.20.25.png](attachment:%E8%9E%A2%E5%B9%95%E5%BF%AB%E7%85%A7%202019-09-30%20%E4%B8%8B%E5%8D%889.20.25.png)

# %% [markdown]
# ## Prototype Implementation
# - Method 1 Implement IClonable interface, and implemnt Clone method, we can return new object in this clone method

# %% [markdown]
# ![%E8%9E%A2%E5%B9%95%E5%BF%AB%E7%85%A7%202019-09-30%20%E4%B8%8B%E5%8D%889.42.02.png](attachment:%E8%9E%A2%E5%B9%95%E5%BF%AB%E7%85%A7%202019-09-30%20%E4%B8%8B%E5%8D%889.42.02.png)

# %% [markdown]
# ### Method 2. Copy Constructtor
# - Copy Constructor ，把該物件裡面所有定義的的資訊給新的物件 ( 把欲複製的物件內所定義的屬性派值到新的物件屬性上 )

# %% [markdown]
#  ![%E8%9E%A2%E5%B9%95%E5%BF%AB%E7%85%A7%202019-09-30%20%E4%B8%8B%E5%8D%889.51.38.png](attachment:%E8%9E%A2%E5%B9%95%E5%BF%AB%E7%85%A7%202019-09-30%20%E4%B8%8B%E5%8D%889.51.38.png)

# %% [markdown]
# ### Method 3. Explicit Deep Copy Interface
# - 與 Method 1 類似，差一點在實作的介面是我們自己定義具有泛型的介面，但有一個缺點，若有很多的cclass 都想要設計 Prototype pattern, 那這樣的方式會使code 變得凌亂，難以管理，故有以下方法幫助我們解決這樣的問題，

# %% [markdown]
# ### Method 4. Copy through Serization
# - extension method
#     - {access-modifier} static class
#         - {access-modifier} static {return_type} {ext_func name}
#             - (this {the type you want to extend} obj, {parameter you will take when you use this ext_methods of obj} )
# - 基本上就是透過 Extension Method 結合 Generic 幫助我們能夠去做到 序列化或是去序列化來複製物件
#     - 但要注意在轉換的過程當中，當前被轉換的class 是否滿足序列化的格式
#     - using System.Runtime.Serialization.Formatters.Binary;
#     - using System.Xml.Serialization;
#     - Exaplnation: object => stream =>formatter(other formatSerializer) => stream => object
#         1. Stream ->
#         2. formatter.Serialize(stream,self) 序列化自身物件 ->
#         3. formatter.seek() : 幫助我們尋找Stream 的位置，以利們後續該從哪裡"開始"讀取
#         4. formatter.Deserialized(sttream) => return object
#         5. Sttream.Close()

# %% [markdown]
# ![%E8%9E%A2%E5%B9%95%E5%BF%AB%E7%85%A7%202019-09-30%20%E4%B8%8B%E5%8D%8810.34.13.png](attachment:%E8%9E%A2%E5%B9%95%E5%BF%AB%E7%85%A7%202019-09-30%20%E4%B8%8B%E5%8D%8810.34.13.png)

# %% [markdown]
# ### Conclusion
# - Partially COnstriutured object and storr ir
# - Implement Clone Function ( can Customized like using interface, serizlize and deserialize )
# - Customized the object after cloning

# %% [markdown]
# ![%E8%9E%A2%E5%B9%95%E5%BF%AB%E7%85%A7%202019-10-08%20%E4%B8%8B%E5%8D%8810.16.03.png](attachment:%E8%9E%A2%E5%B9%95%E5%BF%AB%E7%85%A7%202019-10-08%20%E4%B8%8B%E5%8D%8810.16.03.png)
