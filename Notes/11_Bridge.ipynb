# %% [markdown]
# ### Connect components together through abstractions
# - Bridge pattern avoid Cartesian product complexity explosion

# %% [markdown]
# ### 1.1 Before

# %% [markdown]
# ![%E8%9E%A2%E5%B9%95%E5%BF%AB%E7%85%A7%202019-10-27%20%E4%B8%8B%E5%8D%884.23.39.png](attachment:%E8%9E%A2%E5%B9%95%E5%BF%AB%E7%85%A7%202019-10-27%20%E4%B8%8B%E5%8D%884.23.39.png)

# %% [markdown]
# ### 1.2 After

# %% [markdown]
# ![%E8%9E%A2%E5%B9%95%E5%BF%AB%E7%85%A7%202019-10-27%20%E4%B8%8B%E5%8D%884.23.54.png](attachment:%E8%9E%A2%E5%B9%95%E5%BF%AB%E7%85%A7%202019-10-27%20%E4%B8%8B%E5%8D%884.23.54.png)

# %% [markdown]
# ### 1.3 Intro

# %% [markdown]
# ![%E8%9E%A2%E5%B9%95%E5%BF%AB%E7%85%A7%202019-10-27%20%E4%B8%8B%E5%8D%884.22.18.png](attachment:%E8%9E%A2%E5%B9%95%E5%BF%AB%E7%85%A7%202019-10-27%20%E4%B8%8B%E5%8D%884.22.18.png)

# %% [markdown]
# # 2. Example
# - 善用 Interface 概括畫的寫法 注重IoC (Inversion of Control ) 與 DI (Dependency Injection)
#     - 在欲使用到的 class 裡面中，當中的建構子帶入某介面的參數（dependency Injection ），而真正帶入時可以帶入 已實作介面的子類別所產生的物件，並且透過 liskov inversion 完成實作，避免 cartesian product 問題
#     - Depedency Injection
#         - 透過建構子注入或是property 注入
# - 可以善用 Autofac - ContainerBuilder 來幫助我們實踐
# - Link : https://ithelp.ithome.com.tw/articles/10156571

# %% [markdown]
# ![%E8%9E%A2%E5%B9%95%E5%BF%AB%E7%85%A7%202019-10-27%20%E4%B8%8B%E5%8D%885.10.05.png](attachment:%E8%9E%A2%E5%B9%95%E5%BF%AB%E7%85%A7%202019-10-27%20%E4%B8%8B%E5%8D%885.10.05.png)

# %% [markdown]
# ![%E8%9E%A2%E5%B9%95%E5%BF%AB%E7%85%A7%202019-10-27%20%E4%B8%8B%E5%8D%885.42.34.png](attachment:%E8%9E%A2%E5%B9%95%E5%BF%AB%E7%85%A7%202019-10-27%20%E4%B8%8B%E5%8D%885.42.34.png)
