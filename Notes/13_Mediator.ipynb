# %% [markdown]
# ### 4.11 Introduction

# %% [markdown]
# ![%E8%9E%A2%E5%B9%95%E5%BF%AB%E7%85%A7%202020-04-11%20%E4%B8%8B%E5%8D%888.21.16.png](attachment:%E8%9E%A2%E5%B9%95%E5%BF%AB%E7%85%A7%202020-04-11%20%E4%B8%8B%E5%8D%888.21.16.png)

# %% [markdown]
# ### Application
# - ChatRoom
# - EventtBroker
# - PingCommand and PingResponse (use MediatR library to implement Mediator design pattern)

# %% [markdown]
# ![%E8%9E%A2%E5%B9%95%E5%BF%AB%E7%85%A7%202020-04-11%20%E4%B8%8B%E5%8D%8810.27.06.png](attachment:%E8%9E%A2%E5%B9%95%E5%BF%AB%E7%85%A7%202020-04-11%20%E4%B8%8B%E5%8D%8810.27.06.png)
