# %% [markdown]
# ![%E8%9E%A2%E5%B9%95%E5%BF%AB%E7%85%A7%202020-04-12%20%E4%B8%8B%E5%8D%882.27.37.png](attachment:%E8%9E%A2%E5%B9%95%E5%BF%AB%E7%85%A7%202020-04-12%20%E4%B8%8B%E5%8D%882.27.37.png)

# %% [markdown]
# ### Dependency Injecton : 提升code's lossy coupling 程度
#     -- 建構子注入
#     -- 方法注入
#     -- 屬性注入
#     -- 基本上就是三種方式建立 不同component/object 之間的關係
#     -- 可以透過 Autofac 去建立 DI Ccontainer, 幫助我們管理這些不同component 這些相依性注入的規則
#         -- 一但需求更動, 不太需要改太多code

# %% [markdown]
# ![%E8%9E%A2%E5%B9%95%E5%BF%AB%E7%85%A7%202020-04-12%20%E4%B8%8B%E5%8D%883.45.41.png](attachment:%E8%9E%A2%E5%B9%95%E5%BF%AB%E7%85%A7%202020-04-12%20%E4%B8%8B%E5%8D%883.45.41.png)
